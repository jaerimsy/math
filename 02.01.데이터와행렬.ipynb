# %%
from sklearn.datasets import load_iris
import numpy as np

# %%
iris = load_iris()
iris.data[0,:]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
print(iris.data[0,:])
# Out:
# [5.1 3.5 1.4 0.2]

# %%
x1 = np.array([5.1,3.5,1.4,0.2])
x1
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
x2 = np.array(iris.data[2,:])
x2
# Out:
# array([4.7, 3.2, 1.3, 0.2])

# %%
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

digits = load_digits()
samples=[0,10,20,30,1,11,21,31] #선택한 이미지 번호

d=[]
for i in range(len(samples)):
    d.append(digits.images[samples[i]])

#path = 'C:\\WINDOWS\\Fonts\\NanumGothic.ttf'
#font_name = fm.FontProperties(fname=path, size=50).get_name()
#plt.rc('font', family=font_name)
    
plt.figure(figsize=(8,2))
for i in range(len(samples)):
    plt.subplot(1,8,i+1)
    plt.imshow(d[i], interpolation='nearest', cmap=plt.cm.bone_r)
    plt.grid(False); plt.xticks([]); plt.yticks([])
plt.suptitle("숫자0과 1 이미지", fontsize=20)
plt.tight_layout()
plt.show()

# %%
v = []
for i in range(8):
    v.append(d[i].reshape(64, 1))  # 벡터화
    
plt.figure(figsize=(8, 3))
for i in range(8):
    plt.subplot(1, 8, i + 1)
    plt.imshow(v[i], aspect=0.4,
               interpolation='nearest', cmap=plt.cm.bone_r)
    plt.grid(False); plt.xticks([]); plt.yticks([])
    plt.title("벡터 {}".format(i + 1))
plt.suptitle("벡터화된 이미지", y=1.05)
plt.tight_layout(w_pad=7)
plt.show()

# %%
A = np.array([[11,12,13],[21,22,23]])
A
# Out:
# array([[11, 12, 13],
#        [21, 22, 23]])

# %%
#연습문제2.1.2. Numpy를 사용해서 붓꽃데이터 X에 대한 행렬변수 x를 만들어라.
from sklearn.datasets import load_iris

iris = load_iris()
X = np.array(iris.data)

#print(iris.keys())
#print(iris.data)
#print(iris.data[0:2,-1])

# %%
# Tensor
from scipy import misc 

img_rgb = misc.face()
img_rgb.shape
# Out:
# (768, 1024, 3)

# %%
plt.subplot(221)
plt.imshow(img_rgb, cmap=plt.cm.gray)  # 컬러 이미지 출력
plt.axis("off")
plt.title("RGB 컬러 이미지")

plt.subplot(222)
plt.imshow(img_rgb[:, :, 0], cmap=plt.cm.gray)  # red 채널 출력
plt.axis("off")
plt.title("Red 채널")

plt.subplot(223)
plt.imshow(img_rgb[:, :, 1], cmap=plt.cm.gray)  # green 채널 출력
plt.axis("off")
plt.title("Green 채널")

plt.subplot(224)
plt.imshow(img_rgb[:, :, 2], cmap=plt.cm.gray)  # blue 채널 출력
plt.axis("off")
plt.title("Blue 채널")

plt.show()

# %%
#전치연산
A = np.array([[1,2,3],[4,5,6]])
A
A.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
#연습문제 2.1.3 
#1. Numpy를 이용하여 Iris Data X의 전치행렬 X.T
#2. NumPy를 사용해서 위 전치행렬을 다시 전치한 행렬 (XT)T을 구한다. 이 행렬과 원래 행렬 X을 비교한다.

print(iris.keys())
X=np.array(iris.data)
#XT = X.T
#XT.T
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
np.zeros([3,1]) #영벡터
np.ones([3,1]) #일벡터
#정방행렬
np.diag([1,2,3]) #대각행렬
np.identity(3) #항등행렬
np.eye(3) #항등행렬
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
